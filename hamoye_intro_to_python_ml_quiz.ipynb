# %% [markdown]
# <a href="https://colab.research.google.com/github/msamichael/hamoye-python-ml-quiz/blob/master/hamoye_intro_to_python_ml_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c53119a-c81f-4630-9528-fd34919b8dbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c53119a-c81f-4630-9528-fd34919b8dbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding = "latin-1")
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
wine_row = df[df["Item"] == "Wine"]
wine_row
# Out:
#        Area Code      Area  Item Code  Item  Element Code  \
# 916            4   Algeria       2655  Wine          5511
# 917            4   Algeria       2655  Wine          5611
# 918            4   Algeria       2655  Wine          5072
# 919            4   Algeria       2655  Wine          5911
# 920            4   Algeria       2655  Wine          5301
# ...          ...       ...        ...   ...           ...
# 60551        181  Zimbabwe       2655  Wine          5142
# 60552        181  Zimbabwe       2655  Wine           645
# 60553        181  Zimbabwe       2655  Wine           664
# 60554        181  Zimbabwe       2655  Wine           674
# 60555        181  Zimbabwe       2655  Wine           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 916                                Production      1000 tonnes  52.00   10.0
# 917                           Import Quantity      1000 tonnes   7.00    8.0
# ...

# %%
wine_row_2015_sum = wine_row.groupby("Item")['Y2015'].sum()
wine_row_2015_sum
# Out:
# Item
# Wine    4251.81
# Name: Y2015, dtype: float64

# %%
wine_row_2018_sum = wine_row.groupby("Item")['Y2018'].sum()
wine_row_2018_sum
# Out:
# Item
# Wine    4039.32
# Name: Y2018, dtype: float64

# %%
df.groupby("Area")["Y2017"].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
processing_row = df[ df["Element"] == "Processing"]
processing_row.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Processing    292836.0
# Name: Y2017, dtype: float64

# %%
ar1 = np.array([[94,89,63],
                [93,92,48],
                [92,94,56]])

# %%
ar1[:2, 1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %%
df.groupby("Area")["Y2017"].sum().sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
len(df.groupby("Area")["Y2017"].sum())
# Out:
# 49

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
y = [(2,4),(7,8),(1,5,9)]
x = y[1][1]
x
# Out:
# 8

# %%
stvariation_row = df[ df["Element"] == "Stock Variation"]
stvariation_row
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 13             4   Algeria       2905  Cereals - Excluding Beer          5072
# 29             4   Algeria       2511        Wheat and products          5072
# 45             4   Algeria       2805         Rice and products          5072
# 60             4   Algeria       2513       Barley and products          5072
# 75             4   Algeria       2514        Maize and products          5072
# ...          ...       ...        ...                       ...           ...
# 60842        181  Zimbabwe       2763              Pelagic Fish          5072
# 60853        181  Zimbabwe       2764        Marine Fish, Other          5072
# 60914        181  Zimbabwe       2928             Miscellaneous          5072
# 60924        181  Zimbabwe       2680               Infant food          5072
# 60934        181  Zimbabwe       2899             Miscellaneous          5072
#
# ...

# %%
stvariation_row.groupby("Element")["Y2014"].sum()
# Out:
# Element
# Stock Variation    58749.83
# Name: Y2014, dtype: float64

# %%
stvariation_row.groupby("Element")["Y2015"].sum()
# Out:
# Element
# Stock Variation    34910.99
# Name: Y2015, dtype: float64

# %%
stvariation_row.groupby("Element")["Y2016"].sum()
# Out:
# Element
# Stock Variation    33140.12
# Name: Y2016, dtype: float64

# %%
stvariation_row.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Stock Variation    54316.91
# Name: Y2017, dtype: float64

# %%
stvariation_row.groupby("Element")["Y2018"].sum()
# Out:
# Element
# Stock Variation    20577.91
# Name: Y2018, dtype: float64

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
round(df.Y2017.mean(), 2)
# Out:
# 140.92

# %%
round(df.Y2017.std(), 2)
# Out:
# 1671.86

# %%
Protein_supply_row= df[df["Element"] == "Protein supply quantity (g/capita/day)"]
Protein_supply_row
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 3              4   Algeria       2901               Grand Total           674
# 6              4   Algeria       2903          Vegetal Products           674
# 9              4   Algeria       2941           Animal Products           674
# 25             4   Algeria       2905  Cereals - Excluding Beer           674
# 41             4   Algeria       2511        Wheat and products           674
# ...          ...       ...        ...                       ...           ...
# 60903        181  Zimbabwe       2769   Aquatic Animals, Others           674
# 60911        181  Zimbabwe       2775            Aquatic Plants           674
# 60921        181  Zimbabwe       2928             Miscellaneous           674
# 60931        181  Zimbabwe       2680               Infant food           674
# 60941        181  Zimbabwe       2899             Miscellaneous           674
#
# ...

# %%
Madagascar_protein_supply = Protein_supply_row[Protein_supply_row["Area"] == "Madagascar"]
Madagascar_protein_supply
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718        129  Madagascar       2901               Grand Total
# 30721        129  Madagascar       2903          Vegetal Products
# 30724        129  Madagascar       2941           Animal Products
# 30740        129  Madagascar       2905  Cereals - Excluding Beer
# 30756        129  Madagascar       2511        Wheat and products
# ...          ...         ...        ...                       ...
# 32113        129  Madagascar       2769   Aquatic Animals, Others
# 32123        129  Madagascar       2775            Aquatic Plants
# 32133        129  Madagascar       2928             Miscellaneous
# 32142        129  Madagascar       2680               Infant food
# 32152        129  Madagascar       2899             Miscellaneous
#
#        Element Code                                 Element          Unit  \
# 30718           674  Protein supply quantity (g/capita/day)  g/capita/day
# ...

# %%
Madagascar_protein_supply["Y2015"].sum()
# Out:
# 173.04999999999998
